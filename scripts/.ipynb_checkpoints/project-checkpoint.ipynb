# %%
import requests
import json
import pymongo
from bs4 import BeautifulSoup

# %%
connection = pymongo.MongoClient("mongodb://localhost")
db = connection.user_data
record = db.user_data
print record
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), u'user_data'), u'user_data')

# %%
def get_followers(f) :
    if ',' in f :
        return int(f.replace(',' , ''))
    elif 'k' in f :
        return float(f.replace('k' , ''))*1000
    elif 'm' in f :
        return float(f.replace('m' , ''))*1000000
    else :
        return int(f)

# %%
def get_data(username) :
    link = "https://www.instagram.com/" + username
    req = requests.get(link).text
    soup = BeautifulSoup(req, "html.parser")

    title = str(soup.find('title'))
    
    if "Page Not Found" in title :
        return
    
    ########## Followers/Following ##########
    for i in soup.find_all('meta') :
        try :
            if "Followers" in i['content']  :
                data = i['content'].split(", ")
            followers = get_followers(data[0].split(" ")[0])
            following = get_followers(data[1].split(" ")[0])
            if followers == 0 :
                followers = 1
            break
        except :
            pass
        
    ########## Profile Details ##########
    script = str(soup.find_all('script')[2])
    data = json.loads(script[52:-10])
    profile = data['entry_data']['ProfilePage'][0]

    name = profile['user']['full_name']
    id = profile['user']['id']
    bio = profile['user']['biography']
    posts_cnt = int(profile['user']['media']['count'])
    nodes = profile['user']['media']['nodes']

    ind = posts_cnt
    total_likes = 0
    total_comments = 0

    for node in nodes :
        comments = int(node['comments']['count'])
        likes = int(node['likes']['count'])
        total_likes += likes
        total_comments += comments
        ind -= 1

    like_rate = total_likes / float(10 * followers)
    comment_rate = total_comments / float(10 * followers)
    eng_rate = (total_likes + total_comments) / float(10 * followers)

    obj = {}
    obj['name'] = name
    obj['id'] = int(id)
    obj['followers'] = followers
    obj['following'] = following
    obj['bio'] = bio
    obj['posts'] = int(posts_cnt)
    obj['likes'] = total_likes
    obj['comments'] = total_comments
    obj['engagement_rate'] = eng_rate
    obj['comment_rate'] = comment_rate
    obj['like_rate'] = like_rate
    
    record.insert(obj)
    
    return eng_rate

# %%
def categorise(username) :
    try :
        link = "https://www.instagram.com/" + username
        req = requests.get(link).text
        soup = BeautifulSoup(req, "html.parser")
    except :
        pass
        
    ########## Followers/Following ##########
    for i in soup.find_all('meta') :
        try :
            if "Followers" in i['content']  :
                data = i['content'].split(", ")
            followers = get_followers(data[0].split(" ")[0])
            following = get_followers(data[1].split(" ")[0])
            break
        except :
            pass
        
    try :
        if followers < 100 :
            lt_100.append(username)
        elif followers < 1000 :
            lt_1k.append(username)
        elif followers < 10000 :
            lt_10k.append(username)
        elif followers < 100000 :
            lt_100k.append(username)
        elif followers < 1000000 :
            lt_1m.append(username)
        elif followers < 10000000 :
            lt_10m.append(username)
        elif followers < 100000000 :
            lt_100m.append(username)
    except :
        pass

# %%
get_data("my_instangram_")

# %%
f = open('dataset.txt','r')
cnt = 1
for line in f :
    get_data(line.strip('\n'))
    print cnt, line.strip('\n')
    cnt += 1
# Out:
# 1 my_instangram_
# C:\Users\a3may\Anaconda2\lib\site-packages\ipykernel_launcher.py:63: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
# 2 qiulinzhou
# 3 lily_tebbutt
# 4 sootandty
# 5 sonocco
# 6 denneck
# 7 serkansokmen
# 8 ike_mina
# 9 ez_hee
# 10 ksenaiv
# 11 lollydoeslondon
# 12 ericguillemainphoto
# 13 issydacre
# 14 ivy_xiii
# 15 kimh67
# 16 clonesnclownsblog
# 17 __jbrown__
# 18 marieclaireuk
# 19 sanmeei
# 20 s_pon_y
# 21 t.hagi1013
# 22 londonbus_cruisingparty
# 23 ssoyam
# 24 sunkyung.k
# 25 lisabeithfischer
# 26 tomokoong
# 27 aspiringkennedy
# 28 lvd_89
# 29 campaignforwool
# 30 coffeebythehudson
# 31 leabodker
# 32 imusmanhaider
# 33 miyamans
# 34 hyongmanee
# 35 thelegalshrimp
# 36 donchan27
# 37 raqui3324
# 38 laurence_coste
# 39 ym_plain
# 40 _elsterchen
# 41 ahncc
# 42 erbizzles
# 43 kesang169
# 44 laramelitamonro
# 45 tarissima
# 46 taka44asa
# 47 bevchurchillcurtis
# 48 rebelbrook
# 49 _a_ra_jang
# 50 vladaboss
# 51 threeapplesfell
# 52 air.daichi6
# 53 c_lamct
# 54 charlottegale823
# 55 xligoonx
# 56 saymyname_msalicia
# 57 kavehghoreishi
# 58 shitdabudo
# 59 gtdav1
# 60 hello___helly
# 61 fizzle_28
# 62 al9aihad
# 63 95_yny
# 64 mleamandine
# 65 i_am_kimmy_lol
# 66 georgiana.bande
# 67 hayoun0309
# 68 marienaomi
# 69 bisfitness
# 70 sarah_carr1991
# 71 2mini.jh
# 72 shelbycampbell77
# 73 fitosaravia
# 74 katekuh
# 75 suga.san
# 76 yoonanhee
# 77 domziie89
# 78 pigmoremore
# 79 imcummingmichael
# 80 girlinprada
# 81 kaaatevn
# 82 takaiam
# 83 especialkelly
# 84 robbisen
# 85 oliviabumble
# 86 vibuk
# 87 uksocascene
# 88 franziskawoohoo
# 89 nicholeamara
# 90 villegasbueno
# 91 lumine_xx
# 92 maricar1208
# 93 tsujiokubeniimo
# 94 ashleyjinkyung
# 95 j_____jgh
# 96 lazarides
# 97 vmllondon
# 98 shipunovich
# 99 maayah_s
# 100 florencebridge
# 101 tommena
# 102 destinoshing
# 103 lii_rajib
# 104 tul_jed
# 105 binfaraj
# 106 miquimel
# 107 minabilling
# 108 jdyyy_
# 109 alykh
# 110 dewyflower___
# 111 naa1616
# 112 eventphotosnyc
# 113 annahlmartin88
# 114 reggalado
# 115 zookie_official
# 116 smokeyvolvos
# 117 christysapone
# 118 crealee
# 119 paola_mtl
# 120 esmelampard
# 121 mitro_tv
# 122 joshuadrewyou
# 123 xcristina7
# 124 mashylakor
# 125 hktc
# 126 only.brands
# 127 mediamarmalade
# 128 africa.23
# 129 jguttenberg
# 130 kellyannekelleher
# 131 rin_riinn
# 132 luxsure
# 133 mandylalala
# 134 korlanmadi
# 135 chaniris
# 136 georgesroma
# 137 suvinon
# 138 kseni_efimova
# 139 kupila_milla
# 140 karihalvor
# 141 _sssupermin
# 142 lenasokol
# 143 krylishkina
# 144 mikeshilov
# 145 lucilia.piloto
# 146 behnoud.aprin
# 147 john_tw_hutton
# 148 nicolejseymour
# 149 chihomaruko
# 150 teamjltcondor
# 151 mcardet
# 152 buturki1001
# 153 2hyewon_
# 154 sophiemindell
# 155 mathildablombergs
# 156 imonkey_x9
# 157 mstillytilda
# 158 _danielws
# 159 slimlina
# 160 aisooda.hoseini
# 161 liza.chernaya.2203
# 162 k___and___a
# 163 sasha_zhu_
# 164 liao_meiling
# 165 xx.shakiiraa.xx
# 166 alexikvasnikov
# 167 zancsta
# 168 margherita_serpieri
# 169 emmamatildah
# 170 kovalusha_oks
# 171 elisaberlin
# 172 dml_moscow
# 173 yachnik
# 174 mikeshilov
# 175 jana_bontrager
# 176 hefring1
# 177 amuchnik
# 178 beautyart2013
# 179 filatov_kirill
# 180 ladykarnaval
# 181 amandabliss
# 182 _bibiiloveyou_
# 183 _takoe
# 184 suzymorrison
# 185 aurelielee
# 186 anti_antonin_kalife
# 187 triumphantscoop
# 188 annaurbangirl
# 189 onlychasingthesun
# 190 thomasdmatthews
# 191 chiarabernava
# 192 aloisedmbs
# 193 sophie24anthony
# 194 mashafokina
# 195 clementgarreau
# 196 pischetolaa
# 197 atmosphere_music
# 198 holl_v
# 199 muddareni
# 200 magaesberg
# 201 damienpiron
# 202 thishasallhappenedbefore
# 203 luisamosello
# 204 russelleby
# 205 kcabanikova
# 206 ebbzet
# 207 i_brazil
# 208 dr.chemwilliam
# 209 negin_alsofii
# 210 ilacozzy
# 211 bn.cat
# 212 amuchnik
# 213 korksenia
# 214 patrman76
# 215 racy578
# 216 maricampos
# 217 schoolsucks112
# 218 londonspam
# 219 neil_banks
# 220 laurenrowlandd
# 221 tatianasolomina
# 222 jrm.s
# 223 alenadze
# 224 edabetuel
# 225 yohannaedge
# 226 staffstudio
# 227 denisediamanti
# 228 __missdina__
# 229 alinainwndrlnd
# 230 paul_dorling
# 231 shabbystyleberlin
# 232 angele_douche
# 233 sharlyshawodrei
# 234 salutepinklips
# 235 danielxatamanenko
# 236 tagafriendsweden
# 237 b3nn0suk3
# 238 yulalu
# 239 santanderkarent
# 240 jo_mommaa
# 241 kontraproduktiv_
# 242 mpuzei
# 243 alina_lomonosova
# 244 nikkichabre
# 245 komolova_sofya
# 246 kovaleniks
# 247 thomasknights
# 248 shahabshimarik
# 249 gtnd_sn
# 250 katoninstagram
# 251 thomasgharris
# 252 katerinanatalevna
# 253 xxedds
# 254 klimov__ivan
# 255 paulasdias
# 256 papi_ross7
# 257 annekathrinyeah
# 258 sjlboardman
# 259 nikikobrick
# 260 deuszek
# 261 _thxgod_
# 262 ludvigstrand
# 263 missmadelene66
# 264 gugutishvili_d.g
# 265 _dilara_biebssyy
# 266 mahdiyarp
# 267 dlevesque8
# 268 kishi_haha
# 269 vanesslowgren
# 270 enza73
# 271 leahborelli
# 272 _____mery._____
# 273 ana_sara_91
# 274 finola718
# 275 aarumii
# 276 jaredehenderson
# 277 kaprinski
# 278 amir_4kids
# 279 gle_boy_la
# 280 33miga
# 281 alessio_style
# 282 hanbit1
# 283 jessgebhart
# 284 julie_gaika
# 285 rodry_gox
# 286 jenlovesflowers
# 287 showroom_stylewoman
# 288 healthy_livinng
# 289 sissikotaki
# 290 philipgloss
# 291 bahman_behrouz
# 292 supersonicsound
# 293 omidgholami8
# 294 rosieturner_x
# 295 miss.bells
# 296 oxsimiron2014
# 297 yaniesinnn
# 298 lucygnappy
# 299 tubbytay
# 300 sissigoetze
# 301 meintjesjoane
# 302 n4
# 303 mirageshop_j
# 304 mirageshop_j
# 305 mirageshop_j
# 306 the_earl_of_b
# 307 mirageshop_j
# 308 mirageshop_j
# 309 marticapitanio
# 310 shim_dajung
# 311 mengaofficial
# 312 marcellocortelletti
# 313 songxixi
# 314 tammycranston
# 315 nishiyan1121
# 316 brookehummer
# 317 syphona
# 318 samuila
# 319 imperatrice_plum
# 320 imperatrice_plum
# 321 jennypher_oyes
# 322 zarilena
# 323 cesarepolini
# 324 merry_lahee
# 325 lolag86
# 326 javiermldr
# 327 thatgirlcatiasofia_
# 328 shadylady222
# 329 shadylady222
# 330 reek_nj
# 331 shadylady222
# 332 shadylady222
# 333 tovivienne
# 334 shadylady222
# 335 alexsossah
# 336 shadylady222
# 337 iramomon82
# 338 isabelladgnt
# 339 torresbruna
# 340 guiopeniche_arq
# 341 pandoraboxny
# 342 azatuuui
# 343 pigeon_bb
# 344 albertoripari
# 345 paddy_wagstaff
# 346 siripornonline
# 347 p3rryp3rry
# 348 djkaosjollyjams
# 349 klakette
# 350 madhur6789
# 351 dariozema
# 352 hosein.rahmati22
# 353 veramartynov
# 354 mamajoyanne
# 355 deanoinwonderland
# 356 trial_and_terroir
# 357 kigikato
# 358 gaonnoori_chloe
# 359 annietrinha
# 360 j_sassy
# 361 valeria_pol
# 362 seifullina
# 363 johnny_simoes
# 364 krn323
# 365 gelileo_12
# 366 y_gini
# 367 alohavancouver
# 368 brianaleblond
# 369 devilish_di
# 370 sade4cupcakes
# 371 inaki_mp
# 372 thuchainzzzz
# 373 britishrockart
# 374 britishrockart
# 375 youngtakee
# 376 pezzakezza
# 377 alliedevarona
# 378 begs01
# 379 ham.2
# 380 saskialcooper
# 381 phr_kelly
# 382 k_a_t_i_e_p_w_a_n_g
# 383 imonkey_x9
# 384 noemakosuth
# 385 jayjonas
# 386 risa_clores
# 387 geekara11
# 388 kstarl777
# 389 seebymuse
# 390 crystal0510
# 391 robertostay
# 392 stevepitron
# 393 naokimatsudaa
# 394 ciarly1967
# 395 salutepinklips
# 396 tokyoryoma
# 397 lee_hj_md
# 398 catonjourney
# 399 mark_sutcliffe
# 400 umemalein
# 401 extrablock
# 402 soporificer
# 403 syo23
# 404 testudinal
# 405 diva_eats_world
# 406 piyoocoo
# 407 notjustdrums
# 408 badazzfitcouple
# 409 kathysin
# 410 great.y.s
# 411 shota_machida
# 412 pinnnnnnnng
# 413 ddaddadda_official
# 414 yoyo_g37s
# 415 wwwmoa
# 416 dulcats
# 417 siccus_stockholm
# 418 lysssssl
# 419 yuaner1113
# 420 indiarosejames
# 421 fubuprincess
# 422 anasstasiawarhol
# 423 alphadeltadak
# 424 bbemeankitty
# 425 reum_ss
# 426 kocklotta
# 427 pavel168
# 428 piercii
# 429 bishnya
# 430 tanjalanza
# 431 irresistor
# 432 maybetoi
# 433 wunderbarmoscow
# 434 wunderbarmoscow
# 435 i.slavinskaya
# 436 wunderbarmoscow
# 437 onotaka1985
# 438 wunderbarmoscow
# 439 mishiko_official
# 440 k_hs__
# 441 badsanta21
# 442 onotaka1985
# 443 qiulinzhou
# 444 play_sh
# 445 xx9azu9xx
# 446 yulyasakharova
# 447 mark_wickline
# 448 l__jeun
# 449 sukimina
# 450 hillhillllll
# 451 pooow91
# 452 wrest_school
# 453 qn84
# 454 haraja_deri
# 455 caviarblack
# 456 victorytoris
# 457 geum_b
# 458 moooooooooom
# 459 be_hk
# 460 semhar_82
# 461 heedorinim
# 462 anneforver21
# 463 alannam1
# 464 cettejeunefille
# 465 karisprocter
# 466 ianski168
# 467 morsanj
# 468 chiarakuvvet
# 469 styleinswitzerland
# 470 annetaliana
# 471 wuterrie
# 472 inky666
# 473 n.hmmm
# 474 ciocan
# 475 dubrovina_furs
# 476 nathaliefooo
# 477 sokol.elizaveta
# 478 modettesverige
# 479 thetruth59
# 480 angie25191
# 481 hirofumiya
# 482 crisonni01
# 483 arashzand64
# 484 surgeon_rezeda
# 485 beautyofawoman1
# 486 just_be_crazy
# 487 monikeopi
# 488 mehdi_anakin
# 489 terry_186cm
# 490 peacockbride
# 491 naganook
# 492 parvazesahar
# 493 _mitstabishi_
# 494 elombe
# 495 niklasastrom
# 496 sofia_martin18
# 497 armp20
# 498 yammy_mylittlememory
# 499 hsjun118
# 500 louisens
# 501 krogguiden
# 502 sarah_camp
# 503 victoriaolivia10
# 504 yangjia0w0
# 505 khommm
# 506 rubberboatrobber
# 507 maskcoco
# 508 varen070
# 509 arabic.chameh.group
# 510 arabic.chameh.group
# 511 kusochki_schastya
# 512 jassimali1980
# 513 dal89
# 514 deluxe_by_ls
# 515 almirus
# 516 helensandvik
# 517 _mr_uta_
# 518 shpenuyk
# 519 ananapril
# 520 love_and_.smile
# 521 metossj
# 522 gonzvadanielle
# 523 claudiaciervob
# 524 3milan
# 525 nobu76
# 526 _jessicaskaryd
# 527 helloceline62
# 528 hellomangee
# 529 dont_worry_be_sporty
# 530 kristinastici
# 531 kolessso
# 532 sophievictoriag
# 533 hairbyjess.se
# 534 sangremia
# 535 _1999.11.06_
# 536 chirelhassine
# 537 hongahn_studio
# 538 feriiii111
# 539 herrrickardsoderberg
# 540 mimsin_ms
# 541 yoloire
# 542 serenanaban
# 543 jamjam7956
# 544 miyadc
# 545 jamjam7956
# 546 tattooistwoori
# 547 jamjam7956
# 548 next_numb
# 549 ahn.428
# 550 koreaclubellui
# 551 sarahlailabel
# 552 chantel211
# 553 fielemiele2
# 554 bsodbsod
# 555 markusburoalici
# 556 eleonoirescam
# 557 mp.18_
# 558 _gray7_
# 559 o_ryo
# 560 manonloubaki
# 561 madsenmaria
# 562 a.brahma
# 563 alainga_
# 564 aishi
# 565 aishi
# 566 daddywyman
# 567 byaliaa
# 568 dongbiao0405
# 569 blackqueen_nunu
# 570 mustaschadvisor
# 571 adele__love
# 572 michelledoodles
# 573 melanie_ng1012
# 574 victoriamsk
# 575 jessicaabuchanann
# 576 skypurple8
# 577 joej_o_e
# 578 guldsmen
# 579 city_nail_bar
# 580 jamjam7956
# 581 sarfrazi
# 582 chiarettap
# 583 raheleh_pazhouhan
# 584 smile_0712
# 585 daniel_w95
# 586 sashacaptain
# 587 daniel_w95
# 588 pollypriday
# 589 jamjam7956
# 590 black_ssu
# 591 oliviafayerosee
# 592 cacheux.charlotte
# 593 jamjam7956
# 594 jamjam7956
# 595 jamjam7956
# 596 fajarmeza
# 597 _ajfernebija_
# 598 4b4.k
# 599 jamjam7956
# 600 polaathome
# 601 psh_sit
# 602 queen_hair_moscow
# 603 praktika_stilya
# 604 stephanie_crates
# 605 thedapperdad
# 606 theinsectshoppe
# 607 galo4kali
# 608 open_fashion_concierge
# 609 fawn_j
# 610 judithassouline
# 611 rs_alsuwaidi
# 612 sashanti
# 613 jw.lee
# 614 sjoberg_daniel
# 615 photoshin426
# 616 smile_kou
# 617 natashakyz
# 618 amy_dellara
# 619 petite_aventuriere
# 620 laxinthecity
# 621 ylee_08
# 622 iijimakunio
# 623 tazaraaaaxx
# 624 emmiie_baaby
# 625 01samon
# 626 thatsitfood
# 627 m.mariia_
# 628 lulla_p
# 629 t_v_a_l_e_n_t_i_n_o_
# 630 frejahind
# 631 millarm12
# 632 ssunix
# 633 krystal_lao
# 634 jack_samara
# 635 ssunix
# 636 misswduan
# 637 fashion_confession
# 638 jwpsiemens
# 639 _kana308
# 640 puknyaw
# 641 440matudo
# 642 plato_q
# 643 u.be.u
# 644 litlking
# 645 eve_mulcahy
# 646 stil.shtuchki
# 647 antillaise_243
# 648 mehdi_anakin
# 649 minic05
# 650 dandooodles
# 651 sultana__s
# 652 gallerinagirl
# 653 crevvluv
# 654 skylover99
# 655 daiwamiya
# 656 illidee
# 657 irinamoviegram
# 658 anana.s_22
# 659 nunushin
# 660 kostetc
# 661 victor_lenin
# 662 ryot630
# 663 amandinechaignotparis.london
# 664 ma_pinono
# 665 beedaviesillustration
# 666 allumerjewellery
# 667 gusev1789
# 668 shinycenter
# 669 miofish_
# 670 agataem
# 671 1064_designer
# 672 ely.x7
# 673 wanderer_keiko
# 674 jessicaantonini_
# 675 lilla_clacla
# 676 guch0703
# 677 sandrostefanini
# 678 es4343
# 679 thomasdmatthews
# 680 thomasdmatthews
# 681 philipsandrewap
# 682 wanderer_keiko
# 683 eddiejdm
# 684 m.mariia_
# 685 veusty_78
# 686 jjung1226
# 687 kreulgala
# 688 pinkpippaperkins
# 689 happy_yoga
# 690 alkaled09
# 691 mrtolmach
# 692 wanderer_keiko
# 693 minshikyun
# 694 alireza__alone
# 695 djawb
# 696 dreaminpoems
# 697 nestkinski
# 698 erinriagolden
# 699 denrooijen
# 700 leakrooss
# 701 a15baby
# 702 annarslanova
# 703 taiyaki16
# 704 wanderer_keiko
# 705 sara_abdullah_s
# 706 yan________
# 707 bloodpurple
# 708 ja_eun99
# 709 tanjastraumberg
# 710 sweet_candy29_08
# 711 koto3san
# 712 _sevda.es_
# 713 antoinecaupert
# 714 amieparrott
# 715 yunaa_k
# 716 erion22
# 717 monemilk
# 718 purple_home
# 719 xhannahwilliams
# 720 guliaa_s
# 721 cricchii
# 722 einalemelonx
# 723 cozy_ism
# 724 felixfriede
# 725 swj229
# 726 risky_ricky
# 727 veritas_kochubey
# 728 komissionnyin1
# 729 kitty1096
# 730 polandov1
# 731 _8_jjini
# 732 nokuri28
# 733 saehoon
# 734 joaocastrosousa
# 735 burgerhouse_vrn
# 736 paris7jours
# 737 sinsa725
# 738 sandy_rondy
# 739 lack00danishlab
# 740 _alibuse_
# 741 freeenchtoast
# 742 k.hiroshima
# 743 boweiy
# 744 na_hyome
# 745 redleb1
# 746 arethacarmen
# 747 fujiwaramones
# 748 esmeraldacortesi
# 749 kk_shuz
# 750 ameliastuartxx
# 751 robivent23
# 752 larssporrong
# 753 eathealthygirl
# 754 tozirestaurant
# 755 simon.dempsey
# 756 ila_ila85
# 757 wild__baby
# 758 natalirodnaja
# 759 imfamous_
# 760 djkimc
# 761 piagrahnsthlm
# 762 gldnblue
# 763 s_kulik_
# 764 morgannorman
# 765 ingenstans127
# 766 wagsg126
# 767 miojiichan
# 768 dongri.yoo
# 769 mikaila1981
# 770 miguelito127
# 771 lilyann1296
# 772 luxury_davz
# 773 yoon_wonju
# 774 hitomiifukuda
# 775 m.a.moghadam.73
# 776 8bitrich
# 777 anjaontherocks
# 778 kdo02
# 779 hotseatchamp
# 780 sjoesti
# 781 masmimis
# 782 cabecanaareia
# 783 adrian_pet
# 784 lachanelcharly
# 785 aisbaby415
# 786 cas310
# 787 marciofernandes37
# 788 paolinaab
# 789 kitty_kat333
# 790 kellymg07
# 791 domziie89
# 792 peopletalkru
# 793 cyberbully.mom
# 794 humphs90158
# 795 clemkru
# 796 alexcastillon_
# 797 abdulla960096
# 798 rinnani
# 799 leenasuk
# 800 theonlygrant
# 801 mrcrosbie
# 802 polly_smartgirl
# 803 sevendream
# 804 necozawaemi
# 805 carlocsc31
# 806 dafnegoldenfang
# 807 _mini.queen_
# 808 gres8
# 809 app_zilla
# 810 iamericafletcher
# 811 cstoledo
# 812 so_masy
# 813 mimistic02
# 814 lak.nailbar
# 815 a.n.a.m.e.o.w
# 816 tronkers25
# 817 alicelippart
# 818 susianne_
# 819 monikeopi
# 820 strandphoto
# 821 nyura_chiz
# 822 ba_moriage
# 823 jaccabral
# 824 novseul
# 825 henryzen
# 826 andishafira
# 827 lifeisaholiday
# 828 kinodiva
# 829 alesya_mons
# 830 novseul
# 831 topo9314
# 832 ubirkedal
# 833 rbates88
# 834 annakurap
# 835 _evbruno_
# 836 reutskayasofia
# 837 yv1an
# 838 helsinki_missy
# 839 iamdjsubzero
# 840 sarathe1st
# 841 giulia_bormida
# 842 jchokk
# 843 ashrafariff
# 844 ukiukiuki77
# 845 lindasofiekarlsson
# 846 canadianjennifer
# 847 jelenabujanovic
# 848 thedjlexx
# 849 rbatzz
# 850 mimamalin
# 851 sabinasugar
# 852 clar1968
# 853 megantalarwen
# 854 fandomsgalorekaz
# 855 elisabetehlers
# 856 thomasnordin
# 857 barbarafacciotto
# 858 iva_shenceva
# 859 emilybruni
# 860 natappletiser
# 861 monsieursept
# 862 mvhtap
# 863 liamzaguri
# 864 lindsay.escobar
# 865 rainaami
# 866 juliomcginley
# 867 zoyafox
# 868 ailolovexx
# 869 g.i.u.l.i.a.i.a.c.o
# 870 mr_ap
# 871 thomasclxrke
# 872 huntdebs
# 873 daydream3er
# 874 zoyafox
# 875 mitry.grankov
# 876 ssetare
# 877 shioricoco0805
# 878 yleniapazienza
# 879 tazmania85fg
# 880 _aleksia
# 881 narseniev
# 882 ruzhe_s
# 883 iva_shenceva
# 884 martine.lightblue
# 885 anitabugvohra
# 886 theletteref
# 887 zalinahair
# 888 saaraalk
# 889 jademustapha
# 890 ludovicabarraco
# 891 fouzzi_smaili
# 892 robin_paulsson
# 893 indira_lea
# 894 asyaaksenova
# 895 nail_boss15
# 896 ruthwalters83
# 897 bushahab77
# 898 lauraschwedt
# 899 maratka_kz
# 900 adamzomlot
# 901 angelika_voroshilova
# 902 bennivalori
# 903 super_trolleur_
# 904 talgolani
# 905 yeah_angie
# 906 doseofvitaminf
# 907 xjbabyx9
# 908 slaversia
# 909 tsiresybingue
# 910 kurott
# 911 robin_paulsson
# 912 disman88
# 913 ohsocrumbtious
# 914 kelseyellie_x
# 915 bmwcs
# 916 violett_violett_
# 917 blages_al
# 918 daydream3er
# 919 isabel__arcos
# 920 o2project
# 921 ksusha_bo
# 922 lnhmd80
# 923 nickidarkly
# 924 jcmro
# 925 maiia717
# 926 simo_me70
# 927 valeria_dlz
# 928 chptrck
# 929 xjulia1
# 930 13_pilot
# 931 alixnicolx
# 932 hasan_yalnizoglu_fan
# 933 rauljr.garcia
# 934 upanddiemagazine
# 935 justyara
# 936 ismmsi
# 937 isabelle_mae23
# 938 that_girl_meg
# 939 sonyamintz
# 940 schachamin
# 941 msouzankari
# 942 fyndigt
# 943 giulia_tavani
# 944 alicegerner
# 945 jana_garrett
# 946 petekingston
# 947 kezza3007
# 948 shahadbeauty
# 949 rararogerthat
# 950 giulia_tavani
# 951 nawaras
# 952 k_aladidi
# 953 queens.sg
# 954 nudgiekins
# 955 sailorswidow
# 956 theroamingjedi
# 957 smariana
# 958 kcastillo2_
# 959 anlis14
# 960 sparpack
# 961 itsevecameron_
# 962 mariche1224
# 963 djmsal
# 964 chococook2
# 965 chococook2
# 966 chococook2
# 967 marcosjackes
# 968 nl_rbn
# 969 keythesavage
# 970 laursastre
# 971 jessiwg
# 972 lephoto365
# 973 cactus.pot
# 974 ken109305
# 975 fredsjoberg
# 976 11010design
# 977 donna_p29
# 978 chococook
# 979 3rublya
# 980 sharniemccourt
# 981 tobiasperanza
# 982 yrral1978ph
# 983 facts2real
# 984 mister_simond
# 985 dr.carpio
# 986 gozdegurbak
# 987 bellisima_lila
# 988 phoomnop
# 989 n.zarrrin
# 990 oksi_laff
# 991 thefinalfandom
# 992 taebj007
# 993 greenerrr
# 994 jjeonghwalee
# 995 jjeonghwalee
# 996 hamagon705
# 997 choi_yuni
# 998 waruo
# 999 gracefrohlich
# 1000 i_am_eh_
# 1001 iamkimhyo
# 1002 megatronn214
# 1003 megatronn214
# 1004 michellelllf
# 1005 srhjdic
# 1006 darabascara
# 1007 cmekita
# 1008 misslindaliu
# 1009 seein.kim
# 1010 _dreamist_
# 1011 kgh0220
# 1012 hysk_yb
# 1013 laurenmlv
# 1014 yoosaroo
# 1015 2isora
# 1016 kittymiel
# 1017 d.valarezo
# 1018 almisehal
# 1019 beforesunrise21
# 1020 kandes_traveldiary
# 1021 andersbjorklund
# 1022 chihi327
# 1023 _ryoch1n_
# 1024 minisoda1004
# 1025 mytravelpixels
# 1026 amirhossien1980
# 1027 choajoan14
# 1028 kearrns
# 1029 91.917
# 1030 vikiclare
# 1031 ikuramaki
# 1032 habesha_queen87
# 1033 happytwins1203
# 1034 cherrietam
# 1035 mihara5
# 1036 cmekita
# 1037 next_7_
# 1038 haliluyaaustin
# 1039 danielchavezbello
# 1040 itaijin
# 1041 amandacarl
# 1042 alyaaboulhosn
# 1043 tayumo3160
# 1044 elocin_ecal
# 1045 gendy85
# 1046 estherhuynh
# 1047 wego_jo
# 1048 newstarkim
# 1049 ladolcevitaberlin
# 1050 hajiwata
# 1051 till_havoc
# 1052 e3xmmm
# 1053 kizmhny_er.n5
# 1054 younglady_a
# 1055 geolani_grandz
# 1056 ashleeholmes
# 1057 changsmathilda
# 1058 thatbigbadwolfy
# 1059 bbajjy
# 1060 hancai_wang
# 1061 y__kj
# 1062 asuka_ya
# 1063 venadoalegre
# 1064 hinaoko
# 1065 dalcrose
# 1066 dalcrose
# 1067 marina_kuvshinova_
# 1068 lovesuperomeo
# 1069 rendezvous7196
# 1070 yanabyk
# 1071 yung_k
# 1072 yung_k
# 1073 eeesom
# 1074 solncemaya
# 1075 chouchou_louloutte
# ---------------------------------------------------------------------------
# SSLError                                  Traceback (most recent call last)
# <ipython-input-78-b09fceafbf5d> in <module>()
#       2 cnt = 1
#       3 for line in f :
# ----> 4     get_data(line.strip('\n'))
#       5     print cnt, line.strip('\n')
#       6     cnt += 1
#
# <ipython-input-73-5b9d70eb4d52> in get_data(username)
#       1 def get_data(username) :
#       2     link = "https://www.instagram.com/" + username
# ----> 3     req = requests.get(link).text
#       4     soup = BeautifulSoup(req, "html.parser")
#       5
#
# C:\Users\a3may\Anaconda2\lib\site-packages\requests\api.pyc in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# C:\Users\a3may\Anaconda2\lib\site-packages\requests\api.pyc in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# C:\Users\a3may\Anaconda2\lib\site-packages\requests\sessions.pyc in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# C:\Users\a3may\Anaconda2\lib\site-packages\requests\sessions.pyc in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# C:\Users\a3may\Anaconda2\lib\site-packages\requests\adapters.pyc in send(self, request, stream, timeout, verify, cert, proxies)
#     504             if isinstance(e.reason, _SSLError):
#     505                 # This branch is for urllib3 v1.22 and later.
# --> 506                 raise SSLError(e, request=request)
#     507
#     508             raise ConnectionError(e, request=request)
#
# SSLError: HTTPSConnectionPool(host='www.instagram.com', port=443): Max retries exceeded with url: /p_latanus (Caused by SSLError(SSLError("bad handshake: SysCallError(10060, 'WSAETIMEDOUT')",),))

# %%
lt_100 = []
lt_1k =[]
lt_10k = []
lt_100k = []
lt_1m = []
lt_10m = []
lt_100m = []

f = open('dataset.txt','r')
cnt = 1
for line in f :
    categorise(line.strip('\n'))
    print cnt, line.strip('\n')
    cnt += 1

# %%
print lt_1k
# Out:
# []

# %%
print lt_10k
# Out:
# ['zachboakes', 'suilings', 'distorteddesigns', 'jesykaofficial', 'bernshaw1', 'mariomacilau', 'smithandchang', 'seaninsound', 'portuguese_pointer_mason', 'drbadrghaithi', 'j19n0203', 'max.hs7', '_nessy86_', 'shakiraaa_shakiraaa', 'daily_expedition', 'protogerov', 'rosefsoutham', 'pilarcorriasgallery', 'tomjones121', 'shizukahorikawa', 'restockuk', 'peterwilsonn', 'isabellamillie', 't.hagi1013', 'ssoyam', 'laurence_coste', 'xligoonx', 'kavehghoreishi', 'shitdabudo', 'georgiana.bande', 'katekuh']

# %%
print lt_100k
# Out:
# ['stephfeels', 'deltachildren', 'rubyxvance', 'geety83', 'marinko5589', 'marinko5589', 'miharayasuhiro_official', 'philippabywater', 'samcorgi', 'hijkkm', 'qiulinzhou', 'ericguillemainphoto', 'marieclaireuk', 'aspiringkennedy', 'campaignforwool', 'ym_plain']

# %%
print lt_1m
# Out:
# ['mrselfportrait']

# %%
print lt_10m
# Out:
# []

# %%
print lt_100m
# Out:
# []

# %%
# lt_1k =['sahilruhela', 'charu_pathak','karan_datt','sahilruhela','vaibhav.gupta9395','pulkitrohilla','a3mayank','siddhant.gandhi',
#            'sach1n_delhiite','rishabhvarshneyrv','nikkuuu17']
# lt_10k = ['sam25malik','ezhik_amur','priyankak14','kumarvarun19','sidsince1996']
# lt_100k = ['ayush_mehta','gunjangulatii','deyakannesha','advait_vaidya','its_saileee95']
# lt_1m = ['sirino_er','disha.madan','nititaylor','shetroublemaker','asmita_s']
# lt_10m = ['katrinakaif','faroutakhtar','malaikaarorakhanofficial','bhuvan.bam22','thejohnabraham']
users = [lt_1k,lt_10k,lt_100k,lt_1m,lt_10m,lt_100m]

for i in users :
    rate_cnt = 0
    cnt = 0
    for j in i :
        rate = get_data(j)
        if rate > 0 :
            rate_cnt += rate
            cnt += 1
#                 print rate


print "Avg Eng Rate : ", 100*rate_cnt/float(cnt),'%'
# Out:
# Avg Eng Rate :  16.8011832279 %
# Avg Eng Rate :  2.62700306475 %
# Avg Eng Rate :  1.65726087551 %
# Avg Eng Rate :  1.63956681384 %
# Avg Eng Rate :  3.95240635013 %
# Avg Eng Rate :  2.42133666051 %

# %%
def check(username) :
    

rates = [16.8, 10.0, 8.0, 6.0, 3.95, 2.42]
buyed = []
username = "oberoi.manvi"

check(username)
